 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79640, 79656, 79656, 79656, 79656, 79660, 79660, 79664, 79664, 79664, 79664, 79664, 79664, 79664, 79668, 79668, 79668, 79668, 79692, 79692, 79692, 79696, 79696, 79696, 79696, 79700, 79700, 79700, 79700, 79700, 79700, 79700, 79736, 79736, 79736, 79736, 79736, 79736, 79744, 79744, 79744, 79744, 79744, 79744, 79744, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79748, 79752, 79768, 79768, 79768, 79768, 79772, 79772, 79772, 79772, 79772, 79776, 79776, 79776, 79776, 79780, 79784, 79784, 79784, 79784, 79784, 79784, 79788, 79788, 79788, 79788, 79788, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79792, 79588, 75184, 73028, 72588, 64028, 39648, 7540, 0, 0, 0])
plt.legend([swap], ['Swap'])
plt.ylabel('KiB')
plt.show()

# %% [markdown]
# **Значение в** `report.log`:
# ```sh
# 85000000
# ```
#
# **Вывод** `dmesg | grep "mem.bash"`:
# ```sh
# [ 7994.159159] Out of memory: Killed process 16179 (mem.bash) total-vm:6732492kB, anon-rss:6691292kB, file-rss:0kB, shmem-rss:0kB, UID:1000 pgtables:13172kB oom_score_adj:0
# [ 7994.323780] oom_reaper: reaped process 16179 (mem.bash), now anon-rss:0kB, file-rss:0kB, shmem-rss:0kB
# ```

# %% [markdown]
# ## Второй этап
#
# **Значения памяти (свободной и занятой первым и вторым скриптами)**

# %%
mem, = plt.plot([5121920,4969792,4822672,4672960,4528948,4377332,4231768,4084536,3939464,3795076,3596444,3457716,3318496,3228224,3086812,2933376,2767680,2618856,2472752,2322684,2170908,2021840,1875024,1738432,1590512,1442520,1336536,1191564,1043748,916880,771816,626536,478952,329760,183416,204824,132704,133132,136104,132908,133412,130244,130556,135028,136464,144996,134248,127588,124472,129336,120216,3533416,3448768,3374712,3300512,3234380,3165836,3095780,3010140,2936776,2863988,2796448,2724380,2591456,2498912,2442252,2365904,2232832,2171344,2150444,2079552,2003544,1930336,1857816,1786572,1712996,1634364,1561788,1490768,1416880,1344092,1271012,1200964,1126048,1045456,976424,904360,837084,763240,686648,613748,541488,467652,393060,320216,247664,176080,139644,129036,137292,130448,109136])
script2, = plt.plot([13096,86488,159616,232216,305344,378208,451336,523408,596536,669664,740944,811960,882712,955048,980000,1050000,1116000,1186000,1256000,1326000,1395000,1465000,1534000,1604000,1673000,1743000,1813000,1883000,1953000,2022000,2092000,2162000,2232000,2302000,2372000,2441000,2511000,2580000,2650000,2720000,2790000,2859000,2930000,3000000,3070000,3134000,3193000,3252000,3312000,3371000,3417000,3491000,3560000,3629000,3698000,3767000,3837000,3906000,3974000,4044000,4113000,4182000,4252000,4316000,4382000,4451000,4520000,4583000,4653000,4722000,4792000,4862000,4931000,5001000,5070000,5140000,5209000,5279000,5349000,5419000,5488000,5557000,5627000,5696000,5765000,5834000,5904000,5973000,6043000,6112000,6181000,6251000,6320000,6389000,6459000,6528000,6598000,6640000,6676000,6745000,6806000,6830000])
script1, = plt.plot([12604,85992,159912,233304,307224,381144,455064,528192,602112,676032,748104,819384,890664,963528,988000,1058000,1125000,1196000,1267000,1338000,1408000,1479000,1550000,1620000,1690000,1761000,1832000,1902000,1973000,2043000,2113000,2184000,2254000,2325000,2395000,2465000,2537000,2607000,2677000,2747000,2818000,2889000,2960000,3031000,3102000,3167000,3227000,3287000,3347000,3407000,3453000])
plt.legend([mem, script1, script2], ['Mem', 'Script #1', 'Script #2'])
plt.ylabel('KiB')
plt.show()

# %% [markdown]
# **Значения раздела подкачки**

# %%
swap, = plt.plot([972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,972108,971596,971596,971596,971596,971596,971340,968268,919628,771660,581708,434508,331596,254028,171084,29772,0,2464,3312,3328,4668,5124,5360,5420,7312,7312,7340,7536,7584,32500,46776,46908,51868,58744,58748,58748,58756,58868,58884,58912,60060,60152,60216,60216,60216,60220,60380,60380,60380,60404,60700,60700,60700,60704,60812,61028,61028,61040,61296,61364,61364,61364,61368,33684,0,0,0,0])
plt.legend([swap], ['Swap'])
plt.ylabel('KiB')
plt.show()

# %% [markdown]
# **Значение в** `report.log`:
# ```sh
# 46000000
# ```
#
# **Значение в** `report2.log`:
# ```sh
# 92000000
# ```
#
# **Вывод** `dmesg | grep "mem[2]*.bash"`:
# ```sh
# [ 5241.986732] Out of memory: Killed process 8517 (mem.bash) total-vm:3600016kB, anon-rss:3558744kB, file-rss:0kB, shmem-rss:0kB, UID:1000 pgtables:7048kB oom_score_adj:0
# [ 5242.067847] oom_reaper: reaped process 8517 (mem.bash), now anon-rss:0kB, file-rss:0kB, shmem-rss:0kB
# [ 5431.581540] Out of memory: Killed process 8518 (mem2.bash) total-vm:7139728kB, anon-rss:7060292kB, file-rss:0kB, shmem-rss:0kB, UID:1000 pgtables:13968kB oom_score_adj:0
# [ 5431.740632] oom_reaper: reaped process 8518 (mem2.bash), now anon-rss:0kB, file-rss:0kB, shmem-rss:0kB
# ```
#
# ## Вывод
#
# В первом этапе видно, что процесс потратил всю физическую память, а потом из раздела подкачки.
#
# Во втором этапе оба процесса тратили примерно одинаково. После того как первый процесс аварийно завершился освободилась память, которую тут же начал тратить второй.
#
# Помсотрев на значения в `report.log` и `report2.log` можно увидеть что первый процесс дошел примерно до половины размера второго.
#
# Также можно было заметить, что в пяти первых процессах в топе появлялся процесс `kswapd0`, который работает с виртуальной памятью.
#
# # Эксперимент №2
# ---
#
# ## Вывод
#
# Для **K=30** у меня получилось **N=6200000**, что примерно в 14 раз меньше чем из первого задания. Казалось бы, оно должно было отличаться в 30 раз, но так как мы запускаем процессы через секунду, то часть данных уже успевает обрабатываться, и процесс завершится раньше, освободив место для следующих.
